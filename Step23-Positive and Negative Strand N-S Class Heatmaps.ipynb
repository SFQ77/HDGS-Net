# %% [raw]
# Calculate the average numerical matrices of the positive strands of NNFR and SNFR, and visualize these average matrices in the form of heatmaps.

# %%
import numpy as np
import h5py
import matplotlib.pyplot as plt
import seaborn as sns

# Set plotting parameters
plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams.update({
    'font.family': 'sans-serif',
    'font.sans-serif': 'Arial',
    'font.size': 20,  
    'axes.titlesize': 20,  
    'axes.labelsize': 20,  
    'xtick.labelsize': 14,  
    'ytick.labelsize': 14,  
    'legend.fontsize': 20,  
    'figure.dpi': 300,
    'savefig.dpi': 300,
    'savefig.format': 'png',
    'savefig.bbox': 'tight',
    'savefig.pad_inches': 0.1})

# Data loading and processing
def load_h5_data(file_path):
    with h5py.File(file_path, 'r') as f:
        matrices = f['Nuar'][:]
    return matrices

# List of file paths containing all 12 files
file_paths = [
    "TSS-TTS Matrix/matrix_+NNFR-1N-ALL.h5",
    "TSS-TTS Matrix/matrix_+NNFR+1N-ALL.h5",
    "TSS-TTS Matrix/matrix_+SNFR-1N-ALL.h5",
    "TSS-TTS Matrix/matrix_+SNFR+1N-ALL.h5",
    "TSS-TTS Matrix/matrix_+NNFR-2N-ALL.h5",
    "TSS-TTS Matrix/matrix_+NNFR+2N-ALL.h5",
    "TSS-TTS Matrix/matrix_+SNFR-2N-ALL.h5",
    "TSS-TTS Matrix/matrix_+SNFR+2N-ALL.h5",
    "TSS-TTS Matrix/matrix_+NNFR-3N-ALL.h5",
    "TSS-TTS Matrix/matrix_+NNFR+3N-ALL.h5",
    "TSS-TTS Matrix/matrix_+SNFR-3N-ALL.h5",
    "TSS-TTS Matrix/matrix_+SNFR+3N-ALL.h5"]

# Load data from all files
matrices_list = [load_h5_data(file_path) for file_path in file_paths]

# Calculate the average matrix for each file
average_matrices = [np.mean(matrices, axis=0) for matrices in matrices_list]

# Visualization and saving
dinucleotides = ['AA', 'AC', 'AG', 'AT', 'CA', 'CC', 'CG', 'CT',
                 'GA', 'GC', 'GG', 'GT', 'TA', 'TC', 'TG', 'TT']
positions = np.arange(1, 147)

# Create a 3x4 subplot layout
fig, axs = plt.subplots(3, 4, figsize=(18, 14), gridspec_kw={'wspace': 0.3, 'hspace': 0.4})
vmin = min([mat.min() for mat in average_matrices])
vmax = max([mat.max() for mat in average_matrices])

# Update title list to include titles for all 12 files
titles = [
    '+NNFR-1N', '+NNFR+1N', '+SNFR-1N', '+SNFR+1N',
    '+NNFR-2N', '+NNFR+2N', '+SNFR-2N', '+SNFR+2N',
    '+NNFR-3N', '+NNFR+3N', '+SNFR-3N', '+SNFR+3N']

# Plot heatmaps
for i, ax in enumerate(axs.flat):
    im = ax.imshow(average_matrices[i], cmap='viridis', aspect='auto', vmin=vmin, vmax=vmax)
    
    # Set x-axis ticks to appear every 20 positions
    ax.set_xticks(np.arange(0, 146, 20))
    ax.set_xticklabels(positions[::20]) 
    ax.set_yticks(range(16))
    ax.set_yticklabels(dinucleotides)
    ax.set_title(f"{titles[i]} (n={matrices_list[i].shape[0]})", fontweight='bold', pad=10)
    ax.grid(False)

# Add a shared color bar
fig.subplots_adjust(right=0.9)
cbar_ax = fig.add_axes([0.92, 0.15, 0.02, 0.7])
cbar = fig.colorbar(im, cax=cbar_ax)
cbar.set_label('Normalized dinucleotide frequency', fontsize=24, fontweight='bold', labelpad=24)

# Set shared axis labels, adjust x-axis position to the middle
fig.text(0.5, 0.09, "Position along DNA sequence (bp)", fontweight='bold', ha='center', fontsize=24)
fig.text(0.03, 0.5, "Dinucleotide Type", fontweight='bold', va='center', rotation='vertical', fontsize=24)

# Adjust subplot positions to avoid overlap with the color bar
plt.subplots_adjust(left=0.08, right=0.9, bottom=0.15, top=0.9)

# Save the image
plt.savefig("Visualization Charts/Positive chain_heatmap.png", format='png', dpi=300, bbox_inches='tight', pad_inches=0.1)
plt.show()

# %% [raw]
# Calculate the average numerical matrices of the negative strands of NNFR and SNFR, and visualize these average matrices in the form of heatmaps.

# %%
import numpy as np
import h5py
import matplotlib.pyplot as plt
import seaborn as sns

# Set plotting parameters
plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams.update({
    'font.family': 'sans-serif',
    'font.sans-serif': 'Arial',
    'font.size': 20,  
    'axes.titlesize': 20,  
    'axes.labelsize': 20,  
    'xtick.labelsize': 14,  
    'ytick.labelsize': 14,  
    'legend.fontsize': 20,  
    'figure.dpi': 300,
    'savefig.dpi': 300,
    'savefig.format': 'png',
    'savefig.bbox': 'tight',
    'savefig.pad_inches': 0.1})

# Data loading and processing
def load_h5_data(file_path):
    with h5py.File(file_path, 'r') as f:
        matrices = f['Nuar'][:]
    return matrices

# List of file paths containing all 12 files
file_paths = [
    "TSS-TTS Matrix/matrix_-NNFR-1N-ALL.h5",
    "TSS-TTS Matrix/matrix_-NNFR+1N-ALL.h5",
    "TSS-TTS Matrix/matrix_-SNFR-1N-ALL.h5",
    "TSS-TTS Matrix/matrix_-SNFR+1N-ALL.h5",
    "TSS-TTS Matrix/matrix_-NNFR-2N-ALL.h5",
    "TSS-TTS Matrix/matrix_-NNFR+2N-ALL.h5",
    "TSS-TTS Matrix/matrix_-SNFR-2N-ALL.h5",
    "TSS-TTS Matrix/matrix_-SNFR+2N-ALL.h5",
    "TSS-TTS Matrix/matrix_-NNFR-3N-ALL.h5",
    "TSS-TTS Matrix/matrix_-NNFR+3N-ALL.h5",
    "TSS-TTS Matrix/matrix_-SNFR-3N-ALL.h5",
    "TSS-TTS Matrix/matrix_-SNFR+3N-ALL.h5"]

# Load data from all files
matrices_list = [load_h5_data(file_path) for file_path in file_paths]

# Calculate the average matrix for each file
average_matrices = [np.mean(matrices, axis=0) for matrices in matrices_list]

# Visualization and saving
dinucleotides = ['AA', 'AC', 'AG', 'AT', 'CA', 'CC', 'CG', 'CT',
                 'GA', 'GC', 'GG', 'GT', 'TA', 'TC', 'TG', 'TT']
positions = np.arange(1, 147)

# Create a 3x4 subplot layout
fig, axs = plt.subplots(3, 4, figsize=(18, 14), gridspec_kw={'wspace': 0.3, 'hspace': 0.3})  

vmin = min([mat.min() for mat in average_matrices])
vmax = max([mat.max() for mat in average_matrices])

# Update title list to include titles for all 12 files
titles = [
    '-NNFR-1N', '-NNFR+1N', '-SNFR-1N', '-SNFR+1N',
    '-NNFR-2N', '-NNFR+2N', '-SNFR-2N', '-SNFR+2N',
    '-NNFR-3N', '-NNFR+3N', '-SNFR-3N', '-SNFR+3N']

# Plot heatmaps
for i, ax in enumerate(axs.flat):
    im = ax.imshow(average_matrices[i], cmap='viridis', aspect='auto', vmin=vmin, vmax=vmax)
    
    # Set x-axis ticks to appear every 20 positions
    ax.set_xticks(np.arange(0, 146, 20))
    ax.set_xticklabels(positions[::20])  
    
    ax.set_yticks(range(16))
    ax.set_yticklabels(dinucleotides)
    ax.set_title(f"{titles[i]} (n={matrices_list[i].shape[0]})", fontweight='bold', pad=10)
    ax.grid(False)

# Add a shared color bar
fig.subplots_adjust(right=0.9)
cbar_ax = fig.add_axes([0.92, 0.15, 0.02, 0.7])
cbar = fig.colorbar(im, cax=cbar_ax)
cbar.set_label('Normalized dinucleotide frequency', fontsize=24, fontweight='bold', labelpad=24)

# Set shared axis labels, adjust x-axis position to the middle
fig.text(0.5, 0.09, "Position along DNA sequence (bp)", fontweight='bold', ha='center', fontsize=24)
fig.text(0.03, 0.5, "Dinucleotide Type", fontweight='bold', va='center', rotation='vertical', fontsize=24)

# Adjust subplot positions to avoid overlap with the color bar
plt.subplots_adjust(left=0.08, right=0.9, bottom=0.15, top=0.9)

# Save the image
plt.savefig("Visualization Charts/Negative chain_heatmap.png", format='png', dpi=300, bbox_inches='tight', pad_inches=0.1)
plt.show()
